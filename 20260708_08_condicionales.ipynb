# %%
# condicionales

edad = 15

if edad >= 18:
    print("Soy un adulto")
elif edad >=13:
    print("Soy un adolecente")
else:
    print("soy un infante")
# Out:
# Soy un adolecente

# %%
temperatura = 20

if temperatura > 15:
    print("Peligro")
else:
    print("Normal")
# Out:
# Peligro

# %%
numero = int(input("Ingresa el total de la cuenta: "))

if numero > 0:
    print(f"El numero {numero} es positivo")
elif numero < 0:
    print(f"El numero {numero} es negativo")
else:
    print("El númro es cero")

if numero % 2 == 0:
    print(f"El número {numero} es par")
else:
    print(f"El número {numero} es impar")

if numero >= 18:
    print("Es mayor de edad y puede votar")
else:
    print("Es menor de edad y nopuede votar")
# Out:
# El numero 20 es positivo
# El número 20 es par
# Es mayor de edad y puede votar
