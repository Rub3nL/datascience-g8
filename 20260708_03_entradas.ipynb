# %%
nombre = input("Ingresa tu nombre: ")
print(f"Tu nombre es: {nombre}")

# %%
edad = input("Ingresa tu edad: ")
print(f"Tu edad es: {edad}")

# %%
nombre = "Ruben "
print(
    nombre.replace("e","é")
)
print(nombre.strip())
print(len(nombre))
# Out:
# Rubén
# Ruben
# 6

# %%
nombre = "Ruben Limachi"

nombre_separado = nombre.split(" ")
print(nombre_separado)
# Out:
# ['Ruben', 'Limachi']

# %%
# indexacion
nombre = "Perú"
print(nombre[0])
print(nombre[1])
print(nombre[2])
print(nombre[3])

print(nombre[-1])

print(nombre[0:])
# Out:
# P
# e
# r
# ú
# ú
# Perú
