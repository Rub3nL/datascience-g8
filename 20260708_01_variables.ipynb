# %%
print("hola mundo")
# Out:
# hola mundo

# %%
# Variable de texto, cadena o string
nombre: str = "Ruben"
apellido:str = "Limachi"

print(nombre +" "+ apellido)
mi_nombre_completo = f"Mi nombre completo es: {nombre} {apellido}"
print(mi_nombre_completo)

# Variables numericas enteros
edad: int = 35
sueldo:float = 6000.00

print("Mi edad dentro de 5 años será: ",edad + 5)
# Out:
# Ruben Limachi
# Mi nombre completo es: Ruben Limachi
# Mi edad dentro de 5 años será:  40

# %%
nombre = input("Ingresa tu nombre: ")

# %%
print(nombre)
# Out:
# Ruben

# %%
edad = 20
print(type(edad))

altura = 12.3
print(type(altura))

nombre = "Juanita"
print(type(nombre))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
