# %%
diccionario = {
    "Argentina": "Peso argentino",
    "Bolivia": "Boliviano",   
    "Colombia": "Peso colombiano",   
    "Perú": "Sol",      
    "Venezuela": "Bolívar"
}
print(diccionario)
# Out:
# {'Argentina': 'Peso argentino', 'Bolivia': 'Boliviano', 'Colombia': 'Peso colombiano', 'Perú': 'Sol', 'Venezuela': 'Bolívar'}

# %%
diccionario["Bolivia"] = "Peso Boliviano"
print(diccionario)
# Out:
# {'Argentina': 'Peso argentino', 'Bolivia': 'Peso Boliviano', 'Colombia': 'Peso colombiano', 'Perú': 'Sol', 'Venezuela': 'Bolívar'}

# %%
diccionario.keys()
# Out:
# dict_keys(['Argentina', 'Bolivia', 'Colombia', 'Perú', 'Venezuela'])

# %%
diccionario.values()
# Out:
# dict_values(['Peso argentino', 'Peso Boliviano', 'Peso colombiano', 'Sol', 'Bolívar'])

# %%
diccionario.items()
# Out:
# dict_items([('Argentina', 'Peso argentino'), ('Bolivia', 'Peso Boliviano'), ('Colombia', 'Peso colombiano'), ('Perú', 'Sol'), ('Venezuela', 'Bolívar')])

# %%
diccionario.get("Perú")
# Out:
# 'Sol'

# %%
diccionario["Perú"]
# Out:
# 'Sol'

# %%
diccionario["Perú"] = "Sol Peruano"
print(diccionario)
# Out:
# {'Argentina': 'Peso argentino', 'Bolivia': 'Peso Boliviano', 'Colombia': 'Peso colombiano', 'Perú': 'Sol Peruano', 'Venezuela': 'Bolívar'}

# %%
diccionario.update({"Perú": "Sol Peruano"})
print(diccionario)
# Out:
# {'Argentina': 'Peso argentino', 'Bolivia': 'Peso Boliviano', 'Colombia': 'Peso colombiano', 'Perú': 'Sol Peruano', 'Venezuela': 'Bolívar'}

# %%
diccionario.setdefault("Brasil", "Real brasileño")
print(diccionario)
# Out:
# {'Argentina': 'Peso argentino', 'Bolivia': 'Peso Boliviano', 'Colombia': 'Peso colombiano', 'Perú': 'Sol Peruano', 'Venezuela': 'Bolívar', 'Brasil': 'Peso Brazileño'}

# %%
mi_didiccionario = {
    "Argentina": "Peso argentino",
    "Bolivia": "Boliviano",   
    "Colombia": "Peso colombiano",   
    "Perú": "Sol",      
    "Venezuela": "Bolívar"
}

print(len(mi_didiccionario))
# Out:
# 5

# %%
for keys in mi_didiccionario:
    print(keys)
    print(mi_didiccionario[keys])
# Out:
# Argentina
# Peso argentino
# Bolivia
# Boliviano
# Colombia
# Peso colombiano
# Perú
# Sol
# Venezuela
# Bolívar

# %%
for keys,values in mi_didiccionario.items():
    print(keys ,'=', values)
# Out:
# Argentina = Peso argentino
# Bolivia = Boliviano
# Colombia = Peso colombiano
# Perú = Sol
# Venezuela = Bolívar
