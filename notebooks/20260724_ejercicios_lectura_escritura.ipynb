# %%
from typing import Any

def extrac_contenido(ruta: str) -> dict[str]:
    mi_lista = []
    with open(ruta, "r") as f:
        contenido = f.read()       
        lineas = contenido.split("\n")
        for linea in lineas:
            if "lista" in linea.lower():
                continue

            if not linea:
                continue

            if  "instrucciones" in linea.lower():
                break

            mi_lista.append(linea)
            # print(linea)
            # print("-" * 50)
    return mi_lista

contenido = extrac_contenido("../data/estudiantes_python.txt")

print(contenido)
# Out:
# ['Ana Torres, 18, Arequipa, 16.5', 'Luis Ramos, 21, Lima, 14.0', 'María Quispe, 19, Cusco, 18.2', 'Carlos Medina, 22, Arequipa, 11.8', 'Sofía Vargas, 20, Trujillo, 17.4', 'Diego Salazar, 18, Puno, 13.6', 'Valeria Rojas, 23, Lima, 19.0', 'Jorge Flores, 21, Tacna, 12.5', 'Camila Herrera, 19, Arequipa, 15.7', 'Andrés Castillo, 20, Cusco, 10.9']

# %%
class Estudiante:
    def __init__(
            self,
            nombre: str,
            edad: int,
            ciudad: str,
            nota: float
    ) -> None:
        self.nombre = nombre
        self.edad = edad
        self.ciudad = ciudad
        self.nota = nota

class Aula:
    def __init__(
            self,
            estudiantes: list[str]
    ) -> None:
        self.estudiantes: list[Estudiante] = []

        for estudiante in estudiantes:
            info = [item.strip() for item in estudiante.split(",")]  
            estudiante = Estudiante(
                nombre = info[0],
                edad = int(info[1]),
                ciudad = info[2],
                nota = float(info[3])
            )     

            self.estudiantes.append(estudiante)  

    def __len__(self) -> int:
        return len(self.estudiantes)

    def filtro_por_ciudad(self, ciudad: str) -> None:
        for estudiante in self.estudiantes:
            if estudiante.ciudad.lower() == ciudad:
                print(estudiante.nombre)

    def get_aprobados(self, min_nota: int = 13) -> list[str]:
        estudiantes =[]
        for estudiante in self.estudiantes:
            if estudiante.nota >= min_nota:
                estudiantes.append(estudiante.nombre)
        return estudiantes

    def get_num_aprobados(self, min_nota: int = 13) -> int:
           return len(self.get_aprobados(min_nota))

    def export_alumnos(self,ruta: str) -> str:
        with open(ruta,"w") as f:
            f.write("nombre, edad, ciudad, nota\n")

        for estudiante in self.estudiantes:
            with open(ruta, "a") as f:
                f.write(f"{estudiante.nombre},{estudiante.edad},{estudiante.ciudad},{estudiante.nota}\n")

aula = Aula(contenido)
# Out:
# <__main__.Aula object at 0x000001C352B64440>

# %%
aula.filtro_por_ciudad("cusco")
# Out:
# María Quispe
# Andrés Castillo

# %%
aula.export_alumnos("../data/alumnos.csv")

# %%
aula.get_aprobados(min_nota = 15)
# Out:
# ['Ana Torres',
#  'María Quispe',
#  'Sofía Vargas',
#  'Valeria Rojas',
#  'Camila Herrera']
