# %%
# en la consola de  visual code pegamoes uv add numpy
import numpy as np
print(np.__version__)
# Out:
# 2.5.1

# %%
lista = [1,2,4,5]
array = np.array(lista)
type(array)
array.dtype
# Out:
# dtype('int64')

# %%
arr_str = array.astype('str')
print(arr_str)
arr_str.dtype
# Out:
# ['1' '2' '4' '5']
# dtype('<U21')
